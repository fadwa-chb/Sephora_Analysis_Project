# %% [markdown]
# <a href="https://colab.research.google.com/github/fadwa-chb/Sephora_Analysis_Project/blob/main/sephora__data_cleaning_and_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import uuid
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler,MinMaxScaler,OrdinalEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# First data

# %%
df1=pd.read_csv('/content/drive/MyDrive/sephora/brands_w_m_products.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    100 non-null    int64
#  1   brand         100 non-null    object
#  2   COUNT(brand)  100 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.5+ KB

# %%
df1.head(10)
# Out:
#    Unnamed: 0               brand  COUNT(brand)
# 0           0            CLINIQUE            64
# 1           1               Murad            54
# 2           2        Perricone MD            52
# 3           3            Shiseido            52
# 4           4             Origins            45
# 5           5  Kiehl's Since 1851            42
# 6           6     Kate Somerville            41
# 7           7   Peter Thomas Roth            40
# 8           8       Estée Lauder            39
# 9           9               Fresh            39

# %%
df1.tail(10)
# Out:
#     Unnamed: 0              brand  COUNT(brand)
# 90          90              COOLA             4
# 91          91           COVER FX             4
# 92          92              Evian             4
# 93          93          Indie Lee             4
# 94          94              J.One             4
# 95          95  Naturally Serious             4
# 96          96        Nurse Jamie             4
# 97          97      Wander Beauty             4
# 98          98              BECCA             3
# 99          99            Briogeo             3

# %%
df1.shape
# Out:
# (100, 3)

# %% [markdown]
# Check null values

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# brand           0
# COUNT(brand)    0
# dtype: int64

# %% [markdown]
# Check Duplicate Rows

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Remove Missing Brands

# %%
df1.dropna(subset=['brand'], inplace=True)

# %% [markdown]
# Convert Count to Numeric

# %%
df1['COUNT(brand)'] = pd.to_numeric(df1['COUNT(brand)'], errors='coerce')

# %% [markdown]
#   Rename the column

# %%
df1.rename(columns={'COUNT(brand)': 'COUNT'}, inplace=True)

# %%
df1
# Out:
#     Unnamed: 0              brand  COUNT
# 0            0           CLINIQUE     64
# 1            1              Murad     54
# 2            2       Perricone MD     52
# 3            3           Shiseido     52
# 4            4            Origins     45
# ..         ...                ...    ...
# 95          95  Naturally Serious      4
# 96          96        Nurse Jamie      4
# 97          97      Wander Beauty      4
# 98          98              BECCA      3
# 99          99            Briogeo      3
#
# [100 rows x 3 columns]

# %%
df1.drop(['Unnamed: 0'], axis=1, inplace=True, errors='ignore')

# %%
df1
# Out:
#                 brand  COUNT
# 0            CLINIQUE     64
# 1               Murad     54
# 2        Perricone MD     52
# 3            Shiseido     52
# 4             Origins     45
# ..                ...    ...
# 95  Naturally Serious      4
# 96        Nurse Jamie      4
# 97      Wander Beauty      4
# 98              BECCA      3
# 99            Briogeo      3
#
# [100 rows x 2 columns]

# %% [markdown]
# Data types

# %%
df1.dtypes
# Out:
# brand    object
# COUNT     int64
# dtype: object

# %% [markdown]
# Handle NaN values created by the conversion

# %%
df1.dropna(subset=['COUNT'], inplace=True)

# %% [markdown]
# DataFrame after dropping NaN values

# %%
df1
# Out:
#                 brand  COUNT
# 0            CLINIQUE     64
# 1               Murad     54
# 2        Perricone MD     52
# 3            Shiseido     52
# 4             Origins     45
# ..                ...    ...
# 95  Naturally Serious      4
# 96        Nurse Jamie      4
# 97      Wander Beauty      4
# 98              BECCA      3
# 99            Briogeo      3
#
# [100 rows x 2 columns]

# %% [markdown]
# Standardize Brand Names

# %%
df1['brand'] = df1['brand'].str.strip().str.lower()

# %%
df1
# Out:
#                 brand  COUNT
# 0            clinique     64
# 1               murad     54
# 2        perricone md     52
# 3            shiseido     52
# 4             origins     45
# ..                ...    ...
# 95  naturally serious      4
# 96        nurse jamie      4
# 97      wander beauty      4
# 98              becca      3
# 99            briogeo      3
#
# [100 rows x 2 columns]

# %%
df1['brand_id'] = range(1, len(df1) + 1)

# %%
df1
# Out:
#                 brand  COUNT  brand_id
# 0            clinique     64         1
# 1               murad     54         2
# 2        perricone md     52         3
# 3            shiseido     52         4
# 4             origins     45         5
# ..                ...    ...       ...
# 95  naturally serious      4        96
# 96        nurse jamie      4        97
# 97      wander beauty      4        98
# 98              becca      3        99
# 99            briogeo      3       100
#
# [100 rows x 3 columns]

# %% [markdown]
# Second data

# %%
df2 = pd.read_json('/content/drive/MyDrive/sephora/csvjson.json')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0           100 non-null    int64
#  1   brand   100 non-null    object
#  2   name    100 non-null    object
#  3   price   100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.3+ KB

# %%
df2.head()
# Out:
#              brand                                     name  price
# 0  0  Perricone MD  Neuropeptide Smoothing Facial Conformer    495
# 1  1      Guerlain           Orchidée Impériale The Cream    460
# 2  2         SK-II                   Ultimate Revival Cream    385
# 3  3        La Mer                          The Concentrate    370
# 4  4        La Mer                   The Regenerating Serum    345

# %%
df2.shape
# Out:
# (100, 4)

# %% [markdown]
# Check null Values

# %%
df2.isnull().sum()
# Out:
#          0
# brand    0
# name     0
# price    0
# dtype: int64

# %% [markdown]
# Remove rows with missing brand names

# %%
df2.dropna(subset=['brand', 'price'], how='all', inplace=True)  # Removes rows where BOTH 'brand' AND 'price' are NaN

# %%
df2
# Out:
#                     brand                                     name  price
# 0    0       Perricone MD  Neuropeptide Smoothing Facial Conformer    495
# 1    1           Guerlain           Orchidée Impériale The Cream    460
# 2    2              SK-II                   Ultimate Revival Cream    385
# 3    3             La Mer                          The Concentrate    370
# 4    4             La Mer                   The Regenerating Serum    345
# ..  ..                ...                                      ...    ...
# 95  95    StackedSkincare                        PSC Peptide Serum    150
# 96  96            Eve Lom         WHITE Advanced Brightening Serum    150
# 97  97  Peter Thomas Roth            Un-Wrinkle® Turbo Face Serum    150
# 98  98       Perricone MD                        Cold Plasma+ Face    149
# 99  99              Foreo         ESPADA Blue Light Acne Treatment    149
#
# [100 rows x 4 columns]

# %%
df2.dropna(subset=['brand'], inplace=True)

# %% [markdown]
# Remove rows with percentage values in the 'brand' column (and other non-product rows)

# %%
df2 = df2[~df2['brand'].astype(str).str.contains('%')] #remove rows that contains % in the brand column

# %%
df2=df2[~df2['brand'].astype(str).str.contains('Other')]#remove rows that contains Other in the brand column

# %%
df2 = df2[~df2['name'].astype(str).str.contains('é')]
df2 = df2[~df2['name'].astype(str).str.contains('®')]

# %%
df2 = df2[df2['price'].notna()] #remove rows that contains NaN in the price column

# %%
df2
# Out:
#                   brand                                               name  \
# 0    0     Perricone MD            Neuropeptide Smoothing Facial Conformer
# 2    2            SK-II                             Ultimate Revival Cream
# 3    3           La Mer                                    The Concentrate
# 4    4           La Mer                             The Regenerating Serum
# 6    6         Shiseido  Future Solution LX Intensive Firming Contour S...
# ..  ..              ...                                                ...
# 94  94          Eve Lom                    Age Defying Smoothing Treatment
# 95  95  StackedSkincare                                  PSC Peptide Serum
# 96  96          Eve Lom                   WHITE Advanced Brightening Serum
# 98  98     Perricone MD                                  Cold Plasma+ Face
# 99  99            Foreo                   ESPADA Blue Light Acne Treatment
#
#     price
# 0     495
# 2     385
# 3     370
# 4     345
# 6     306
# ..    ...
# 94    150
# 95    150
# 96    150
# 98    149
# 99    149
#
# [89 rows x 4 columns]

# %%
df2
# Out:
#                   brand                                               name  \
# 0    0     Perricone MD            Neuropeptide Smoothing Facial Conformer
# 2    2            SK-II                             Ultimate Revival Cream
# 3    3           La Mer                                    The Concentrate
# 4    4           La Mer                             The Regenerating Serum
# 6    6         Shiseido  Future Solution LX Intensive Firming Contour S...
# ..  ..              ...                                                ...
# 94  94          Eve Lom                    Age Defying Smoothing Treatment
# 95  95  StackedSkincare                                  PSC Peptide Serum
# 96  96          Eve Lom                   WHITE Advanced Brightening Serum
# 98  98     Perricone MD                                  Cold Plasma+ Face
# 99  99            Foreo                   ESPADA Blue Light Acne Treatment
#
#     price
# 0     495
# 2     385
# 3     370
# 4     345
# 6     306
# ..    ...
# 94    150
# 95    150
# 96    150
# 98    149
# 99    149
#
# [89 rows x 4 columns]

# %% [markdown]
# Combine multi-line product names

# %%
 df2['name'] = df2.groupby('brand')['name'].transform(lambda x: '\n'.join(x))
df2.drop_duplicates(subset=['brand','price'],inplace=True)

# %% [markdown]
# Convert 'price' to numeric

# %%
df2['price'] = pd.to_numeric(df2['price'], errors='coerce')

# %% [markdown]
# remove extra spaces from brands

# %%
df2['brand'] = df2['brand'].str.strip()

# %% [markdown]
# remove extra spaces from names

# %%
df2['name'] = df2['name'].str.strip()

# %% [markdown]
# Drop the first column

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#                     brand                                               name  \
# 0    0       Perricone MD  Neuropeptide Smoothing Facial Conformer\nNeuro...
# 1    2              SK-II  Ultimate Revival Cream\nUltimate Revival Essen...
# 2    3             La Mer  The Concentrate\nThe Regenerating Serum\nThe M...
# 3    4             La Mer  The Concentrate\nThe Regenerating Serum\nThe M...
# 4    6           Shiseido  Future Solution LX Intensive Firming Contour S...
# ..  ..                ...                                                ...
# 65  89  Peter Thomas Roth     FIRMx Growth Factor Extreme Neuropeptide Serum
# 66  90    StackedSkincare            EGF Activating Serum\nPSC Peptide Serum
# 67  94            Eve Lom  Age Defying Smoothing Treatment\nWHITE Advance...
# 68  98       Perricone MD  Neuropeptide Smoothing Facial Conformer\nNeuro...
# 69  99              Foreo                   ESPADA Blue Light Acne Treatment
#
#     price
# 0     495
# 1     385
# 2     370
# 3     345
# 4     306
# ..    ...
# 65    150
# 66    150
# 67    150
# 68    149
# 69    149
#
# [70 rows x 4 columns]

# %%
df2.rename(columns={'': 'index'}, inplace=True)

# %%
df2
# Out:
#     index              brand  \
# 0       0       Perricone MD
# 1       2              SK-II
# 2       3             La Mer
# 3       4             La Mer
# 4       6           Shiseido
# ..    ...                ...
# 65     89  Peter Thomas Roth
# 66     90    StackedSkincare
# 67     94            Eve Lom
# 68     98       Perricone MD
# 69     99              Foreo
#
#                                                  name  price
# 0   Neuropeptide Smoothing Facial Conformer\nNeuro...    495
# 1   Ultimate Revival Cream\nUltimate Revival Essen...    385
# 2   The Concentrate\nThe Regenerating Serum\nThe M...    370
# 3   The Concentrate\nThe Regenerating Serum\nThe M...    345
# 4   Future Solution LX Intensive Firming Contour S...    306
# ..                                                ...    ...
# 65     FIRMx Growth Factor Extreme Neuropeptide Serum    150
# 66            EGF Activating Serum\nPSC Peptide Serum    150
# 67  Age Defying Smoothing Treatment\nWHITE Advance...    150
# 68  Neuropeptide Smoothing Facial Conformer\nNeuro...    149
# 69                   ESPADA Blue Light Acne Treatment    149
#
# [70 rows x 4 columns]

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#     index              brand  \
# 0       0       Perricone MD
# 1       2              SK-II
# 2       3             La Mer
# 3       4             La Mer
# 4       6           Shiseido
# ..    ...                ...
# 65     89  Peter Thomas Roth
# 66     90    StackedSkincare
# 67     94            Eve Lom
# 68     98       Perricone MD
# 69     99              Foreo
#
#                                                  name  price
# 0   Neuropeptide Smoothing Facial Conformer\nNeuro...    495
# 1   Ultimate Revival Cream\nUltimate Revival Essen...    385
# 2   The Concentrate\nThe Regenerating Serum\nThe M...    370
# 3   The Concentrate\nThe Regenerating Serum\nThe M...    345
# 4   Future Solution LX Intensive Firming Contour S...    306
# ..                                                ...    ...
# 65     FIRMx Growth Factor Extreme Neuropeptide Serum    150
# 66            EGF Activating Serum\nPSC Peptide Serum    150
# 67  Age Defying Smoothing Treatment\nWHITE Advance...    150
# 68  Neuropeptide Smoothing Facial Conformer\nNeuro...    149
# 69                   ESPADA Blue Light Acne Treatment    149
#
# [70 rows x 4 columns]

# %%
df2.drop('index', axis=1, inplace=True)  # Drop the 'index' column

# %%
df2
# Out:
#                 brand                                               name  \
# 0        Perricone MD  Neuropeptide Smoothing Facial Conformer\nNeuro...
# 1               SK-II  Ultimate Revival Cream\nUltimate Revival Essen...
# 2              La Mer  The Concentrate\nThe Regenerating Serum\nThe M...
# 3              La Mer  The Concentrate\nThe Regenerating Serum\nThe M...
# 4            Shiseido  Future Solution LX Intensive Firming Contour S...
# ..                ...                                                ...
# 65  Peter Thomas Roth     FIRMx Growth Factor Extreme Neuropeptide Serum
# 66    StackedSkincare            EGF Activating Serum\nPSC Peptide Serum
# 67            Eve Lom  Age Defying Smoothing Treatment\nWHITE Advance...
# 68       Perricone MD  Neuropeptide Smoothing Facial Conformer\nNeuro...
# 69              Foreo                   ESPADA Blue Light Acne Treatment
#
#     price
# 0     495
# 1     385
# 2     370
# 3     345
# 4     306
# ..    ...
# 65    150
# 66    150
# 67    150
# 68    149
# 69    149
#
# [70 rows x 3 columns]

# %% [markdown]
# Third data

# %%
df3=pd.read_csv('/content/drive/MyDrive/sephora/product_info.csv')

# %%
df3.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    fragrance discovery set      6342      19-69         6320
# 1    P473668    la habana eau de parfum      6342      19-69         3827
# 2    P473662  rainbow bar eau de parfum      6342      19-69         3253
# 3    P473660       kasbah eau de parfum      6342      19-69         3018
# 4    P473658  purple haze eau de parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0   not specified                                size
# 1  4.1538     13.0  3.4 oz/ 100 ml  size + concentration + formulation
# 2  4.2500     16.0  3.4 oz/ 100 ml  size + concentration + formulation
# 3  4.4762     21.0  3.4 oz/ 100 ml  size + concentration + formulation
# 4  3.2308     13.0  3.4 oz/ 100 ml  size + concentration + formulation
#
#   variation_value  ...  limited_edition  new  online_only  out_of_stock  \
# 0   1.7 oz/ 50 ml  ...                0    0            1             0
# 1  3.4 oz/ 100 ml  ...                0    0            1             0
# 2  3.4 oz/ 100 ml  ...                0    0            1             0
# 3  3.4 oz/ 100 ml  ...                0    0            1             0
# 4  3.4 oz/ 100 ml  ...                0    0            1             0
#
#    sephora_exclusive                                         highlights  \
# 0                  0  ['unisex/ genderless scent', 'warm &spicy scen...
# 1                  0  ['unisex/ genderless scent', 'layerable scent'...
# 2                  0  ['unisex/ genderless scent', 'layerable scent'...
# 3                  0  ['unisex/ genderless scent', 'layerable scent'...
# 4                  0  ['unisex/ genderless scent', 'layerable scent'...
#
#    primary_category  secondary_category  tertiary_category child_count
# 0         fragrance   value & gift sets  perfume gift sets           0
# 1         fragrance               women            perfume           2
# 2         fragrance               women            perfume           2
# 3         fragrance               women            perfume           2
# 4         fragrance               women            perfume           2
#
# [5 rows x 23 columns]

# %%
df3.columns
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'price_usd', 'value_price_usd', 'sale_price_usd', 'limited_edition',
#        'new', 'online_only', 'out_of_stock', 'sephora_exclusive', 'highlights',
#        'primary_category', 'secondary_category', 'tertiary_category',
#        'child_count'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# product_id             object
# product_name           object
# brand_id                int64
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          1000 non-null   object
#  1   product_name        1000 non-null   object
#  2   brand_id            1000 non-null   int64
#  3   brand_name          1000 non-null   object
#  4   loves_count         1000 non-null   int64
#  5   rating              1000 non-null   float64
#  6   reviews             1000 non-null   float64
#  7   size                1000 non-null   object
#  8   variation_type      1000 non-null   object
#  9   variation_value     1000 non-null   object
#  10  price_usd           1000 non-null   float64
#  11  value_price_usd     1000 non-null   float64
#  12  sale_price_usd      1000 non-null   float64
#  13  limited_edition     1000 non-null   int64
#  14  new                 1000 non-null   int64
#  15  online_only         1000 non-null   int64
#  16  out_of_stock        1000 non-null   int64
#  17  sephora_exclusive   1000 non-null   int64
#  18  highlights          1000 non-null   object
#  19  primary_category    1000 non-null   object
#  20  secondary_category  999 non-null    object
#  21  tertiary_category   873 non-null    object
#  22  child_count         1000 non-null   int64
# dtypes: float64(5), int64(8), object(10)
# memory usage: 179.8+ KB

# %%
df3.shape
# Out:
# (1000, 23)

# %% [markdown]
# Handle Missing Values

# %%
df3.isnull().sum()
# Out:
# product_id              0
# product_name            0
# brand_id                0
# brand_name              0
# loves_count             0
# rating                  0
# reviews                 0
# size                    0
# variation_type          0
# variation_value         0
# price_usd               0
# value_price_usd         0
# sale_price_usd          0
# limited_edition         0
# new                     0
# online_only             0
# out_of_stock            0
# sephora_exclusive       0
# highlights              0
# primary_category        0
# secondary_category      1
# tertiary_category     127
# child_count             0
# dtype: int64

# %% [markdown]
# Drop unnecessary columns

# %%
columns_to_drop = ['variation_desc', 'ingredients', 'child_max_price', 'child_min_price']
df3.drop(columns=columns_to_drop, inplace=True, errors='ignore') # errors='ignore' prevents errors if a column doesn't exist

# %% [markdown]
# Standardize text columns (lowercase, remove extra spaces)

# %%
text_cols = ['product_name', 'brand_name', 'primary_category', 'secondary_category', 'tertiary_category', 'size', 'variation_type', 'variation_value', 'highlights']

for col in text_cols:
    if col in df3.columns:  # Check if column exists
        df3[col] = df3[col].astype(str).str.lower().str.strip()
        df3[col] = df3[col].replace(r'\s+', ' ', regex=True)

# %% [markdown]
# Handling Missing Value

# %%
#rating and reviews (since they have the same missing values)
df3['rating'].fillna(0, inplace=True)  # Fill with 0 (meaning no rating)
df3['reviews'].fillna(0, inplace=True)
# Out:
# <ipython-input-308-4d513d1cf5a1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['rating'].fillna(0, inplace=True)  # Fill with 0 (meaning no rating)
# <ipython-input-308-4d513d1cf5a1>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['reviews'].fillna(0, inplace=True)

# %%
df3
# Out:
#     product_id                         product_name  brand_id     brand_name  \
# 0      P473671              fragrance discovery set      6342          19-69
# 1      P473668              la habana eau de parfum      6342          19-69
# 2      P473662            rainbow bar eau de parfum      6342          19-69
# 3      P473660                 kasbah eau de parfum      6342          19-69
# 4      P473658            purple haze eau de parfum      6342          19-69
# ..         ...                                  ...       ...            ...
# 995    P481959           wake the f*ck up deodorant      8007  by rosie jane
# 996    P431765       leila lou perfume travel spray      8007  by rosie jane
# 997    P431444                        rosie perfume      8007  by rosie jane
# 998    P479736  wake the f*ck up everyday body wash      8007  by rosie jane
# 999    P503667              fragrance discovery set      8007  by rosie jane
#
#      loves_count  rating  reviews             size  \
# 0           6320  3.6364     11.0    not specified
# 1           3827  4.1538     13.0   3.4 oz/ 100 ml
# 2           3253  4.2500     16.0   3.4 oz/ 100 ml
# 3           3018  4.4762     21.0   3.4 oz/ 100 ml
# 4           2691  3.2308     13.0   3.4 oz/ 100 ml
# ..           ...     ...      ...              ...
# 995         7318  3.9773     44.0       2oz / 59ml
# 996         5363  4.2931     58.0  0.25 oz/ 7.5 ml
# 997         4794  4.4498    249.0    1.7 oz/ 50 ml
# 998         4567  4.1250      8.0     8 oz/ 236 ml
# 999         4335  4.7635    148.0    not specified
#
#                          variation_type  \
# 0                                  size
# 1    size + concentration + formulation
# 2    size + concentration + formulation
# 3    size + concentration + formulation
# 4    size + concentration + formulation
# ..                                  ...
# 995  size + concentration + formulation
# 996  size + concentration + formulation
# 997  size + concentration + formulation
# 998  size + concentration + formulation
# 999                                size
#
#                                 variation_value  ...  limited_edition  new  \
# 0                                 1.7 oz/ 50 ml  ...                0    0
# 1                                3.4 oz/ 100 ml  ...                0    0
# 2                                3.4 oz/ 100 ml  ...                0    0
# 3                                3.4 oz/ 100 ml  ...                0    0
# 4                                3.4 oz/ 100 ml  ...                0    0
# ..                                          ...  ...              ...  ...
# 995                                  2oz / 59ml  ...                0    0
# 996  0.25 oz/ 7.5 ml eau de parfum travel spray  ...                0    0
# 997           1.7 oz/ 50 ml eau de parfum spray  ...                0    0
# 998                      8 oz/ 236 ml body wash  ...                0    0
# 999                               1.7 oz/ 50 ml  ...                0    0
#
#      online_only  out_of_stock  sephora_exclusive  \
# 0              1             0                  0
# 1              1             0                  0
# 2              1             0                  0
# 3              1             0                  0
# 4              1             0                  0
# ..           ...           ...                ...
# 995            1             0                  0
# 996            0             0                  1
# 997            0             0                  0
# 998            1             0                  0
# 999            1             0                  0
#
#                                             highlights  primary_category  \
# 0    ['unisex/ genderless scent', 'warm &spicy scen...         fragrance
# 1    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 2    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 3    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 4    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# ..                                                 ...               ...
# 995  ['allure 2022 best of beauty award winner', 'c...       bath & body
# 996  ['floral scent', 'clean + planet positive', 'v...         fragrance
# 997  ['vegan', 'layerable scent', 'warm &spicy scen...         fragrance
# 998  ['best for normal skin', 'clean + planet posit...       bath & body
# 999  ['vegan', 'layerable scent', 'clean + planet p...         fragrance
#
#      secondary_category           tertiary_category child_count
# 0     value & gift sets           perfume gift sets           0
# 1                 women                     perfume           2
# 2                 women                     perfume           2
# 3                 women                     perfume           2
# 4                 women                     perfume           2
# ..                  ...                         ...         ...
# 995           body care  deodorant & antiperspirant           0
# 996               women   rollerballs & travel size           0
# 997               women                     perfume           1
# 998       bath & shower      body wash & shower gel           0
# 999   value & gift sets           perfume gift sets           0
#
# [1000 rows x 23 columns]

# %% [markdown]
# Handling missing values

# %%
missing_value_formats = ["nan", " ", ""] #Add all the representations of missing values
for col in ['size','variation_type', 'variation_value', 'highlights']:
    if col in df3.columns:
        df3[col] = df3[col].replace(missing_value_formats, np.nan)

# --- Handling Missing Values ---
fillna_cols = ['size','variation_type', 'variation_value', 'highlights']
for col in fillna_cols:
    if col in df3.columns:
        df3[col] = df3[col].fillna('not specified')

# %%
# --- Handling Missing Values (using SimpleImputer for 'most_frequent') ---
imputer = SimpleImputer(missing_values='not specified', strategy='most_frequent')

df3[['variation_type']] = imputer.fit_transform(df3[['variation_type']])
df3[['variation_value']] = imputer.fit_transform(df3[['variation_value']])
df3[['highlights']] = imputer.fit_transform(df3[['highlights']])

# %%
df3
# Out:
#     product_id                         product_name  brand_id     brand_name  \
# 0      P473671              fragrance discovery set      6342          19-69
# 1      P473668              la habana eau de parfum      6342          19-69
# 2      P473662            rainbow bar eau de parfum      6342          19-69
# 3      P473660                 kasbah eau de parfum      6342          19-69
# 4      P473658            purple haze eau de parfum      6342          19-69
# ..         ...                                  ...       ...            ...
# 995    P481959           wake the f*ck up deodorant      8007  by rosie jane
# 996    P431765       leila lou perfume travel spray      8007  by rosie jane
# 997    P431444                        rosie perfume      8007  by rosie jane
# 998    P479736  wake the f*ck up everyday body wash      8007  by rosie jane
# 999    P503667              fragrance discovery set      8007  by rosie jane
#
#      loves_count  rating  reviews             size  \
# 0           6320  3.6364     11.0    not specified
# 1           3827  4.1538     13.0   3.4 oz/ 100 ml
# 2           3253  4.2500     16.0   3.4 oz/ 100 ml
# 3           3018  4.4762     21.0   3.4 oz/ 100 ml
# 4           2691  3.2308     13.0   3.4 oz/ 100 ml
# ..           ...     ...      ...              ...
# 995         7318  3.9773     44.0       2oz / 59ml
# 996         5363  4.2931     58.0  0.25 oz/ 7.5 ml
# 997         4794  4.4498    249.0    1.7 oz/ 50 ml
# 998         4567  4.1250      8.0     8 oz/ 236 ml
# 999         4335  4.7635    148.0    not specified
#
#                          variation_type  \
# 0                                  size
# 1    size + concentration + formulation
# 2    size + concentration + formulation
# 3    size + concentration + formulation
# 4    size + concentration + formulation
# ..                                  ...
# 995  size + concentration + formulation
# 996  size + concentration + formulation
# 997  size + concentration + formulation
# 998  size + concentration + formulation
# 999                                size
#
#                                 variation_value  ...  limited_edition  new  \
# 0                                 1.7 oz/ 50 ml  ...                0    0
# 1                                3.4 oz/ 100 ml  ...                0    0
# 2                                3.4 oz/ 100 ml  ...                0    0
# 3                                3.4 oz/ 100 ml  ...                0    0
# 4                                3.4 oz/ 100 ml  ...                0    0
# ..                                          ...  ...              ...  ...
# 995                                  2oz / 59ml  ...                0    0
# 996  0.25 oz/ 7.5 ml eau de parfum travel spray  ...                0    0
# 997           1.7 oz/ 50 ml eau de parfum spray  ...                0    0
# 998                      8 oz/ 236 ml body wash  ...                0    0
# 999                               1.7 oz/ 50 ml  ...                0    0
#
#      online_only  out_of_stock  sephora_exclusive  \
# 0              1             0                  0
# 1              1             0                  0
# 2              1             0                  0
# 3              1             0                  0
# 4              1             0                  0
# ..           ...           ...                ...
# 995            1             0                  0
# 996            0             0                  1
# 997            0             0                  0
# 998            1             0                  0
# 999            1             0                  0
#
#                                             highlights  primary_category  \
# 0    ['unisex/ genderless scent', 'warm &spicy scen...         fragrance
# 1    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 2    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 3    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 4    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# ..                                                 ...               ...
# 995  ['allure 2022 best of beauty award winner', 'c...       bath & body
# 996  ['floral scent', 'clean + planet positive', 'v...         fragrance
# 997  ['vegan', 'layerable scent', 'warm &spicy scen...         fragrance
# 998  ['best for normal skin', 'clean + planet posit...       bath & body
# 999  ['vegan', 'layerable scent', 'clean + planet p...         fragrance
#
#      secondary_category           tertiary_category child_count
# 0     value & gift sets           perfume gift sets           0
# 1                 women                     perfume           2
# 2                 women                     perfume           2
# 3                 women                     perfume           2
# 4                 women                     perfume           2
# ..                  ...                         ...         ...
# 995           body care  deodorant & antiperspirant           0
# 996               women   rollerballs & travel size           0
# 997               women                     perfume           1
# 998       bath & shower      body wash & shower gel           0
# 999   value & gift sets           perfume gift sets           0
#
# [1000 rows x 23 columns]

# %%
# --- Handling Missing Values in Numeric Columns (filling with 0) ---
numeric_cols_with_missing = ['rating', 'reviews']
for col in numeric_cols_with_missing:
    if col in df3.columns:
        df3[col] = df3[col].fillna(0)

# %%
# Price related
df3['value_price_usd'] = df3['value_price_usd'].fillna(df3['price_usd'])
df3['sale_price_usd'] = df3['sale_price_usd'].fillna(0)

# %%
df3
# Out:
#     product_id                         product_name  brand_id     brand_name  \
# 0      P473671              fragrance discovery set      6342          19-69
# 1      P473668              la habana eau de parfum      6342          19-69
# 2      P473662            rainbow bar eau de parfum      6342          19-69
# 3      P473660                 kasbah eau de parfum      6342          19-69
# 4      P473658            purple haze eau de parfum      6342          19-69
# ..         ...                                  ...       ...            ...
# 995    P481959           wake the f*ck up deodorant      8007  by rosie jane
# 996    P431765       leila lou perfume travel spray      8007  by rosie jane
# 997    P431444                        rosie perfume      8007  by rosie jane
# 998    P479736  wake the f*ck up everyday body wash      8007  by rosie jane
# 999    P503667              fragrance discovery set      8007  by rosie jane
#
#      loves_count  rating  reviews             size  \
# 0           6320  3.6364     11.0    not specified
# 1           3827  4.1538     13.0   3.4 oz/ 100 ml
# 2           3253  4.2500     16.0   3.4 oz/ 100 ml
# 3           3018  4.4762     21.0   3.4 oz/ 100 ml
# 4           2691  3.2308     13.0   3.4 oz/ 100 ml
# ..           ...     ...      ...              ...
# 995         7318  3.9773     44.0       2oz / 59ml
# 996         5363  4.2931     58.0  0.25 oz/ 7.5 ml
# 997         4794  4.4498    249.0    1.7 oz/ 50 ml
# 998         4567  4.1250      8.0     8 oz/ 236 ml
# 999         4335  4.7635    148.0    not specified
#
#                          variation_type  \
# 0                                  size
# 1    size + concentration + formulation
# 2    size + concentration + formulation
# 3    size + concentration + formulation
# 4    size + concentration + formulation
# ..                                  ...
# 995  size + concentration + formulation
# 996  size + concentration + formulation
# 997  size + concentration + formulation
# 998  size + concentration + formulation
# 999                                size
#
#                                 variation_value  ...  limited_edition  new  \
# 0                                 1.7 oz/ 50 ml  ...                0    0
# 1                                3.4 oz/ 100 ml  ...                0    0
# 2                                3.4 oz/ 100 ml  ...                0    0
# 3                                3.4 oz/ 100 ml  ...                0    0
# 4                                3.4 oz/ 100 ml  ...                0    0
# ..                                          ...  ...              ...  ...
# 995                                  2oz / 59ml  ...                0    0
# 996  0.25 oz/ 7.5 ml eau de parfum travel spray  ...                0    0
# 997           1.7 oz/ 50 ml eau de parfum spray  ...                0    0
# 998                      8 oz/ 236 ml body wash  ...                0    0
# 999                               1.7 oz/ 50 ml  ...                0    0
#
#      online_only  out_of_stock  sephora_exclusive  \
# 0              1             0                  0
# 1              1             0                  0
# 2              1             0                  0
# 3              1             0                  0
# 4              1             0                  0
# ..           ...           ...                ...
# 995            1             0                  0
# 996            0             0                  1
# 997            0             0                  0
# 998            1             0                  0
# 999            1             0                  0
#
#                                             highlights  primary_category  \
# 0    ['unisex/ genderless scent', 'warm &spicy scen...         fragrance
# 1    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 2    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 3    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# 4    ['unisex/ genderless scent', 'layerable scent'...         fragrance
# ..                                                 ...               ...
# 995  ['allure 2022 best of beauty award winner', 'c...       bath & body
# 996  ['floral scent', 'clean + planet positive', 'v...         fragrance
# 997  ['vegan', 'layerable scent', 'warm &spicy scen...         fragrance
# 998  ['best for normal skin', 'clean + planet posit...       bath & body
# 999  ['vegan', 'layerable scent', 'clean + planet p...         fragrance
#
#      secondary_category           tertiary_category child_count
# 0     value & gift sets           perfume gift sets           0
# 1                 women                     perfume           2
# 2                 women                     perfume           2
# 3                 women                     perfume           2
# 4                 women                     perfume           2
# ..                  ...                         ...         ...
# 995           body care  deodorant & antiperspirant           0
# 996               women   rollerballs & travel size           0
# 997               women                     perfume           1
# 998       bath & shower      body wash & shower gel           0
# 999   value & gift sets           perfume gift sets           0
#
# [1000 rows x 23 columns]

# %% [markdown]
# Data Type Conversion

# %%
numeric_cols = ['loves_count', 'rating', 'reviews', 'price_usd', 'value_price_usd', 'sale_price_usd', 'child_count']
for col in numeric_cols:
    if col in df3.columns:
        df3[col] = pd.to_numeric(df3[col], errors='coerce')

# %%
df3.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    fragrance discovery set      6342      19-69         6320
# 1    P473668    la habana eau de parfum      6342      19-69         3827
# 2    P473662  rainbow bar eau de parfum      6342      19-69         3253
# 3    P473660       kasbah eau de parfum      6342      19-69         3018
# 4    P473658  purple haze eau de parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0   not specified                                size
# 1  4.1538     13.0  3.4 oz/ 100 ml  size + concentration + formulation
# 2  4.2500     16.0  3.4 oz/ 100 ml  size + concentration + formulation
# 3  4.4762     21.0  3.4 oz/ 100 ml  size + concentration + formulation
# 4  3.2308     13.0  3.4 oz/ 100 ml  size + concentration + formulation
#
#   variation_value  ...  limited_edition  new  online_only  out_of_stock  \
# 0   1.7 oz/ 50 ml  ...                0    0            1             0
# 1  3.4 oz/ 100 ml  ...                0    0            1             0
# 2  3.4 oz/ 100 ml  ...                0    0            1             0
# 3  3.4 oz/ 100 ml  ...                0    0            1             0
# 4  3.4 oz/ 100 ml  ...                0    0            1             0
#
#    sephora_exclusive                                         highlights  \
# 0                  0  ['unisex/ genderless scent', 'warm &spicy scen...
# 1                  0  ['unisex/ genderless scent', 'layerable scent'...
# 2                  0  ['unisex/ genderless scent', 'layerable scent'...
# 3                  0  ['unisex/ genderless scent', 'layerable scent'...
# 4                  0  ['unisex/ genderless scent', 'layerable scent'...
#
#    primary_category  secondary_category  tertiary_category child_count
# 0         fragrance   value & gift sets  perfume gift sets           0
# 1         fragrance               women            perfume           2
# 2         fragrance               women            perfume           2
# 3         fragrance               women            perfume           2
# 4         fragrance               women            perfume           2
#
# [5 rows x 23 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          1000 non-null   object
#  1   product_name        1000 non-null   object
#  2   brand_id            1000 non-null   int64
#  3   brand_name          1000 non-null   object
#  4   loves_count         1000 non-null   int64
#  5   rating              1000 non-null   float64
#  6   reviews             1000 non-null   float64
#  7   size                1000 non-null   object
#  8   variation_type      1000 non-null   object
#  9   variation_value     1000 non-null   object
#  10  price_usd           1000 non-null   float64
#  11  value_price_usd     1000 non-null   float64
#  12  sale_price_usd      1000 non-null   float64
#  13  limited_edition     1000 non-null   int64
#  14  new                 1000 non-null   int64
#  15  online_only         1000 non-null   int64
#  16  out_of_stock        1000 non-null   int64
#  17  sephora_exclusive   1000 non-null   int64
#  18  highlights          1000 non-null   object
#  19  primary_category    1000 non-null   object
#  20  secondary_category  1000 non-null   object
#  21  tertiary_category   1000 non-null   object
#  22  child_count         1000 non-null   int64
# dtypes: float64(5), int64(8), object(10)
# memory usage: 179.8+ KB

# %%
df3.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    fragrance discovery set      6342      19-69         6320
# 1    P473668    la habana eau de parfum      6342      19-69         3827
# 2    P473662  rainbow bar eau de parfum      6342      19-69         3253
# 3    P473660       kasbah eau de parfum      6342      19-69         3018
# 4    P473658  purple haze eau de parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0   not specified                                size
# 1  4.1538     13.0  3.4 oz/ 100 ml  size + concentration + formulation
# 2  4.2500     16.0  3.4 oz/ 100 ml  size + concentration + formulation
# 3  4.4762     21.0  3.4 oz/ 100 ml  size + concentration + formulation
# 4  3.2308     13.0  3.4 oz/ 100 ml  size + concentration + formulation
#
#   variation_value  ...  limited_edition  new  online_only  out_of_stock  \
# 0   1.7 oz/ 50 ml  ...                0    0            1             0
# 1  3.4 oz/ 100 ml  ...                0    0            1             0
# 2  3.4 oz/ 100 ml  ...                0    0            1             0
# 3  3.4 oz/ 100 ml  ...                0    0            1             0
# 4  3.4 oz/ 100 ml  ...                0    0            1             0
#
#    sephora_exclusive                                         highlights  \
# 0                  0  ['unisex/ genderless scent', 'warm &spicy scen...
# 1                  0  ['unisex/ genderless scent', 'layerable scent'...
# 2                  0  ['unisex/ genderless scent', 'layerable scent'...
# 3                  0  ['unisex/ genderless scent', 'layerable scent'...
# 4                  0  ['unisex/ genderless scent', 'layerable scent'...
#
#    primary_category  secondary_category  tertiary_category child_count
# 0         fragrance   value & gift sets  perfume gift sets           0
# 1         fragrance               women            perfume           2
# 2         fragrance               women            perfume           2
# 3         fragrance               women            perfume           2
# 4         fragrance               women            perfume           2
#
# [5 rows x 23 columns]

# %%
df3.tail()
# Out:
#     product_id                         product_name  brand_id     brand_name  \
# 995    P481959           wake the f*ck up deodorant      8007  by rosie jane
# 996    P431765       leila lou perfume travel spray      8007  by rosie jane
# 997    P431444                        rosie perfume      8007  by rosie jane
# 998    P479736  wake the f*ck up everyday body wash      8007  by rosie jane
# 999    P503667              fragrance discovery set      8007  by rosie jane
#
#      loves_count  rating  reviews             size  \
# 995         7318  3.9773     44.0       2oz / 59ml
# 996         5363  4.2931     58.0  0.25 oz/ 7.5 ml
# 997         4794  4.4498    249.0    1.7 oz/ 50 ml
# 998         4567  4.1250      8.0     8 oz/ 236 ml
# 999         4335  4.7635    148.0    not specified
#
#                          variation_type  \
# 995  size + concentration + formulation
# 996  size + concentration + formulation
# 997  size + concentration + formulation
# 998  size + concentration + formulation
# 999                                size
#
#                                 variation_value  ...  limited_edition  new  \
# 995                                  2oz / 59ml  ...                0    0
# 996  0.25 oz/ 7.5 ml eau de parfum travel spray  ...                0    0
# 997           1.7 oz/ 50 ml eau de parfum spray  ...                0    0
# 998                      8 oz/ 236 ml body wash  ...                0    0
# 999                               1.7 oz/ 50 ml  ...                0    0
#
#      online_only  out_of_stock  sephora_exclusive  \
# 995            1             0                  0
# 996            0             0                  1
# 997            0             0                  0
# 998            1             0                  0
# 999            1             0                  0
#
#                                             highlights  primary_category  \
# 995  ['allure 2022 best of beauty award winner', 'c...       bath & body
# 996  ['floral scent', 'clean + planet positive', 'v...         fragrance
# 997  ['vegan', 'layerable scent', 'warm &spicy scen...         fragrance
# 998  ['best for normal skin', 'clean + planet posit...       bath & body
# 999  ['vegan', 'layerable scent', 'clean + planet p...         fragrance
#
#      secondary_category           tertiary_category child_count
# 995           body care  deodorant & antiperspirant           0
# 996               women   rollerballs & travel size           0
# 997               women                     perfume           1
# 998       bath & shower      body wash & shower gel           0
# 999   value & gift sets           perfume gift sets           0
#
# [5 rows x 23 columns]

# %%
# --- Clean 'brand_name' in df3 (CRUCIAL!) ---
if 'brand_name' in df3.columns:
    df3['brand_name'] = df3['brand_name'].str.strip().str.lower()
else:
    print("Error: 'brand_name' column not found in df3.")
    exit()

# %%
# Create a dictionary mapping brand names to brand_ids from df1
brand_id_map = dict(zip(df1['brand'], df1['brand_id']))

# %%
# Map the brand_ids to df3 based on 'brand_name' ---
df3['brand_id'] = df3['brand_name'].map(brand_id_map)

# %%
# Remove rows with unmatched brand names
df3 = df3.dropna(subset=['brand_id'])

# %%
# Remove decimals from brand_id in df3 (if it's a float column)
if pd.api.types.is_numeric_dtype(df3['brand_id']): #Check if the column is numeric
    df3['brand_id'] = df3['brand_id'].astype(int)
# Out:
# <ipython-input-325-a49c533aeecf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['brand_id'] = df3['brand_id'].astype(int)

# %%
df3.head()
# Out:
#    product_id                                       product_name  brand_id  \
# 89    P439055               genius sleeping collagen moisturizer        11
# 90    P421277                       genius liquid collagen serum        11
# 91    P467602            triple algae eye renewal balm eye cream        11
# 92    P432045               genius liquid collagen lip treatment        11
# 93    P311143  sublime defense ultra lightweight uv defense f...        11
#
#    brand_name  loves_count  rating  reviews           size variation_type  \
# 89   algenist        33910  4.5413   1321.0    2 oz/ 60 ml           size
# 90   algenist        67870  4.0259   1159.0   1 oz / 30 ml           size
# 91   algenist        17890  4.5306   1142.0  not specified           size
# 92   algenist        44448  3.8721    649.0  .5 oz / 15 ml           size
# 93   algenist        27278  4.4134    508.0           1 oz           size
#
#    variation_value  ...  limited_edition  new  online_only  out_of_stock  \
# 89     2 oz/ 60 ml  ...                0    0            0             0
# 90    1 oz / 30 ml  ...                0    0            0             0
# 91   1.7 oz/ 50 ml  ...                0    0            0             0
# 92   .5 oz / 15 ml  ...                0    0            0             0
# 93            1 oz  ...                0    0            0             0
#
#     sephora_exclusive                                         highlights  \
# 89                  1  ['vegan', 'good for: loss of firmness', 'colla...
# 90                  1  ['vegan', 'good for: loss of firmness', 'colla...
# 91                  1                ['layerable scent', 'floral scent']
# 92                  1  ['vegan', 'good for: loss of firmness', 'plump...
# 93                  0  ['vegan', 'hypoallergenic', 'uv protection', '...
#
#     primary_category      secondary_category        tertiary_category  \
# 89          skincare            moisturizers             moisturizers
# 90          skincare              treatments              face serums
# 91          skincare                eye care  eye creams & treatments
# 92          skincare  lip balms & treatments                      nan
# 93          skincare               sunscreen           face sunscreen
#
#    child_count
# 89           0
# 90           1
# 91           0
# 92           0
# 93           0
#
# [5 rows x 23 columns]

# %%
df1
# Out:
#                 brand  COUNT  brand_id
# 0            clinique     64         1
# 1               murad     54         2
# 2        perricone md     52         3
# 3            shiseido     52         4
# 4             origins     45         5
# ..                ...    ...       ...
# 95  naturally serious      4        96
# 96        nurse jamie      4        97
# 97      wander beauty      4        98
# 98              becca      3        99
# 99            briogeo      3       100
#
# [100 rows x 3 columns]

# %%
df1.to_csv('/content/cleaned_data1.csv', index=False)

df3.to_csv('/content/cleaned_data3.csv', index=False)

# Save the JSON dataset
df2.to_json('/content/cleaned_data2.json', orient='records', lines=True)


from google.colab import files
files.download('/content/cleaned_data1.csv')
files.download('/content/cleaned_data3.csv')
files.download('/content/cleaned_data2.json')
